# %%
# %run main.py

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.pyplot as p
epochs = range(1, 101)
plt.plot(epochs, GD_train_err,'black', label='GD')
plt.plot(epochs, Nesterov1_train_err,'blue', label="Nesterov $B=0.9$")
plt.plot(epochs, Nesterov2_train_err,'purple', label="Nesterov $B=0.99$")
plt.legend(bbox_to_anchor=(0.96, 0.96), loc=0, borderaxespad=0.)
p.ylabel('$\%$ Error')
p.xlabel('Epochs')
#p.ylim(0.05, 0.3)  
p.suptitle("Training Error")
p.savefig('part_1_train_err.png',dpi=800, bbox_inches='tight')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['gamma']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
